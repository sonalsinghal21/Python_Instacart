# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
#creating path for future use
path = r'/Users/krishngarg/Downloads/Data Analytics/Data immersion /Achievement_4/06-2020 Instacart Basket Analysis'

# %%
#creating dataframe for order.csv file
df_ords = pd.read_csv(os.path.join(path,'02 Data', 'Orignal Data','orders.csv'),index_col = False)

# %%
df_ords
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %% [markdown]
# # Dropping eval_set column

# %%
#Dropping eval_set column from order.csv file
df_ords = df_ords.drop(columns =['eval_set'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # Renaming column

# %%
#renaming column order_dow
df_ords.rename (columns = {'order_dow' :'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # 4. The Busiest hour for placing orders and find the frequency of corresponding variable.

# %%
#Find highest frequency of order hours.
df_ords['order_hour_of_day'].value_counts()
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# 10 AM has the highest frequency of orders.

# %% [markdown]
# # 5. Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.

# %%
#creating dataframe for department file
df_dep = pd.read_csv(os.path.join(path, '02 Data','Orignal Data','departments.csv'),index_col = False)

# %%
df_dep
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#Transposing df_dep
df_dep_t = df_dep.T

# %%
df_dep_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
#reseting index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#create a new dataframe that only copies over rows beyond the first row.
#take the data under the header row for a new df.
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#set the header row as the df header.
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#creating dictionary for df_dep_t_new
data_dict_dep = df_dep_t_new.to_dict('index')

# %%
data_dict_dep
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_dep_t_new.head()
# Out:
# department_id department
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
#creating dataframe for product_csv file
df_prods = pd.read_csv(os.path.join(path,'02 Data','Orignal Data','products.csv'),index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#print value of 4 in department_id column in product.csv file
print(data_dict_dep.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# Department_id 4 has 'Produce' department name.

# %% [markdown]
# # 6. Create a subset containing only breakfast items information.

# %%
#creating subset for breakfast.
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# # 7. Find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood.

# %%
#creating subset for alcohol, deli, beverages and meat/seafood.
df_dinnerMenu = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
df_dinnerMenu.head(25)
# Out:
#      product_id                                       product_name  aisle_id  \
# 2             3               Robust Golden Unsweetened Oolong Tea        94
# 6             7                     Pure Coconut Water With Orange        98
# 9            10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10           11                                  Peach Mango Juice        31
# 16           17                                  Rendered Duck Fat        35
# 19           20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22           23                             Organic Turkey Burgers        49
# 34           35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38           39           Daily Tangerine Citrus Flavored Beverage        64
# 39           40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43           44                        Sparkling Raspberry Seltzer       115
# ...

# %% [markdown]
# # 8. How many rows does the last dataframe you created have?

# %%
#totl counts of df_dinnerMenu subbset
df_dinnerMenu.shape
# Out:
# (7650, 5)

# %% [markdown]
# # 9. Extract all the information about user_id 1.

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#creating subset for user_id 1
df_ords_user1 = df_ords.loc[df_ords['orders_day_of_week']==3]

# %%
df_ords_user1
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 15        1673511        2             5                   3
# 24         839880        2            14                   3
# 27         444309        3             2                   3
# ...           ...      ...           ...                 ...
# 3421053   2789700   206208            35                   3
# 3421065   2239861   206208            47                   3
# 3421069   3154581   206209             1                   3
# 3421070   1889163   206209             2                   3
# 3421076   2129269   206209             8                   3
#
#          order_hour_of_day  days_since_prior_order
# 1                        7                    15.0
# 2                       12                    21.0
# 15                      11                     8.0
# ...

# %% [markdown]
# # 10. Details about user's behavior.

# %%
df_ords_user1.describe()
# Out:
#            order_id        user_id   order_number  orders_day_of_week  \
# count  4.369720e+05  436972.000000  436972.000000            436972.0
# mean   1.711935e+06  102879.397769      17.821144                 3.0
# std    9.875803e+05   59490.016597      18.464430                 0.0
# min    1.400000e+01       1.000000       1.000000                 3.0
# 25%    8.569095e+05   51338.000000       5.000000                 3.0
# 50%    1.712369e+06  102620.000000      11.000000                 3.0
# 75%    2.567093e+06  154093.000000      24.000000                 3.0
# max    3.421081e+06  206209.000000     100.000000                 3.0
#
#        order_hour_of_day  days_since_prior_order
# count      436972.000000           411314.000000
# mean           13.522555               10.768301
# std             4.275911                9.301918
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# ...

# %% [markdown]
# # 12. Exporting Order file.

# %%
df_ords.to_csv(os.path.join(path,'02 Data', 'orders_wrangled.csv'))

# %% [markdown]
# # 13. Exporting Department file.

# %%
df_dep_t_new.to_csv(os.path.join(path,'02 Data', 'departments_wrangled.csv'))
